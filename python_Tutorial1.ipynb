# %% [markdown]
# <a href="https://colab.research.google.com/github/Monika9763/Jeremy-Howard-Squadron-/blob/main/python_Tutorial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Tutorial
# ## index 1
# ### This is my first session
# ![Vimal_Photo1.jpeg](data:image/jpeg;base64,...)

# %%
import pandas as pd

# %%
a=4;
b=5;
c=a+b;
print(c)
# Out:
# 9
